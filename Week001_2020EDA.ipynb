# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import the saved dataset>>>>>2020 csv file

# %%
df2020 = pd.read_csv("IT Salary Survey EU  2020.csv")
df2020
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# ...

# %% [markdown]
# get a preview of the dataset using .head() function that displays first 5 rows

# %%
df2020.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# checking dataset size

# %%
df2020.shape
# Out:
# (1253, 23)

# %% [markdown]
# checking for missing values and more information about our dataset

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# obtaining summary statistics of the data

# %%
df2020.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %% [markdown]
# check employees gendercomposition

# %%
Gender_count = df2020["Gender"].value_counts()
Gender_count
# Out:
# Male       1049
# Female      192
# Diverse       2
# Name: Gender, dtype: int64

# %% [markdown]
# getting average salary of each gender

# %%
Gender_avg_salary = df2020.groupby('Gender')["Yearly brutto salary (without bonus and stocks) in EUR"].mean()
Gender_avg_salary
# Out:
# Gender
# Diverse    1.445000e+05
# Female     2.662480e+06
# Male       7.384706e+04
# Name: Yearly brutto salary (without bonus and stocks) in EUR, dtype: float64

# %% [markdown]
# checking out correlations inn the dataset

# %%
df2020.corr()
# Out:
#                                                          Age  \
# Age                                                 1.000000
# Yearly brutto salary (without bonus and stocks)... -0.017259
# Annual brutto salary (without bonus and stocks)... -0.024847
# Have you been forced to have a shorter working ... -0.003563
#
#                                                     Yearly brutto salary (without bonus and stocks) in EUR  \
# Age                                                                                         -0.017259
# Yearly brutto salary (without bonus and stocks)...                                           1.000000
# Annual brutto salary (without bonus and stocks)...                                           0.999998
# Have you been forced to have a shorter working ...                                          -0.044144
#
# ...

# %% [markdown]
# creating a correlation matrix

# %%
corr_matrix = df2020.corr()
corr_matrix
# Out:
#                                                          Age  \
# Age                                                 1.000000
# Yearly brutto salary (without bonus and stocks)... -0.017259
# Annual brutto salary (without bonus and stocks)... -0.024847
# Have you been forced to have a shorter working ... -0.003563
#
#                                                     Yearly brutto salary (without bonus and stocks) in EUR  \
# Age                                                                                         -0.017259
# Yearly brutto salary (without bonus and stocks)...                                           1.000000
# Annual brutto salary (without bonus and stocks)...                                           0.999998
# Have you been forced to have a shorter working ...                                          -0.044144
#
# ...

# %% [markdown]
# Now visualizing the correlations on a heatmap

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# drawing a boxplot of age vs yearly pruto salary

# %%
#sns.boxplot(x='Age', y='Yearly brutto salary (without bonus and stocks) in EU')
