# %% [markdown]
# Application Programming Interface-API provide a standardized way for two applications to communicate
#
# API allows you to execute code ona server without getting direct access
#
# Before APIs there was webscraping (Downloading HTML directly froma web and then parsing the results programmatically)
#
# You could have used:
# 1. Beautiful soup
# 2. wget
#
# #Using API
# You access APIs via the web using a web address. within the web address, specify the data that you want.
# Some APIs require that you send login credentials as part of your request.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

url = "http://api.worldbank.org/v2/countries/br;cn;us;de/indicators/SP.POP.TOTL/?format=json&per_page=1000%27"
r = requests.get(url)
r.json()
# Out:
# [{'message': [{'id': '120',
#     'key': 'Invalid value',
#     'value': 'The provided parameter value is not valid'}]}]

# %% [markdown]
# Importing worldbank data python package

# %%
import world_bank_data as wb
pd.set_option('display.max_rows', 6)

# %% [markdown]
# Get the list of topics,

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# ..                              ...
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# 2   Aid effectiveness is the impact that aid has i...
# 3   Economic growth is central to economic develop...
# ..                                                ...
# 19  Climate change is expected to hit developing c...
# 20  Debt statistics provide a detailed picture of ...
# 21  Trade is a key means to fight poverty and achi...
#
# [21 rows x 2 columns]

# %% [markdown]
# Get the list of sources

# %%
wb.get_sources()
# Out:
#    lastupdated                                           name code  \
# id
# 1   2021-08-18                                 Doing Business  DBS
# 2   2022-12-22                   World Development Indicators  WDI
# 3   2022-09-23                Worldwide Governance Indicators  WGI
# ..         ...                                            ...  ...
# 87  2022-10-07  Country Climate and Development Report (CCDR)  CCD
# 88  2022-07-05                      Food Prices for Nutrition  FPN
# 89  2022-12-21     Identification for Development (ID4D) Data  ID4
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# 2                                 Y                    Y        3
# 3                                 Y                    Y        3
# ..         ...  ..              ...                  ...      ...
# 87                                Y                    Y        3
# ...

# %% [markdown]
# getting the list of countries

# %%
wb.get_countries()
# Out:
#     iso2Code                         name                      region  \
# id
# ABW       AW                        Aruba  Latin America & Caribbean
# AFE       ZH  Africa Eastern and Southern                  Aggregates
# AFG       AF                  Afghanistan                  South Asia
# ..       ...                          ...                         ...
# ZAF       ZA                 South Africa         Sub-Saharan Africa
# ZMB       ZM                       Zambia         Sub-Saharan Africa
# ZWE       ZW                     Zimbabwe         Sub-Saharan Africa
#
#                                     adminregion          incomeLevel  \
# id
# ABW                                                      High income
# AFE                                                       Aggregates
# AFG                                  South Asia           Low income
# ..                                          ...                  ...
# ...

# %%
wb.get_incomelevels()
# Out:
#     iso2code                value
# id
# HIC       XD          High income
# INX       XY       Not classified
# LIC       XM           Low income
# ..       ...                  ...
# LMY       XO  Low & middle income
# MIC       XP        Middle income
# UMC       XT  Upper middle income
#
# [7 rows x 2 columns]

# %%
wb.get_indicators(topic=3, source=2)
# Out:
#                                                                 name unit  \
# id
# BG.GSR.NFSV.GD.ZS                       Trade in services (% of GDP)
# BM.GSR.CMCP.ZS     Communications, computer, etc. (% of service i...
# BM.GSR.FCTY.CD            Primary income payments (BoP, current US$)
# ...                                                              ...  ...
# PA.NUS.PPP         PPP conversion factor, GDP (LCU per internatio...
# PA.NUS.PPPC.RF     Price level ratio of PPP conversion factor (GD...
# PA.NUS.PRVT.PP     PPP conversion factor, private consumption (LC...
#
#                                          source  \
# id
# BG.GSR.NFSV.GD.ZS  World Development Indicators
# BM.GSR.CMCP.ZS     World Development Indicators
# BM.GSR.FCTY.CD     World Development Indicators
# ...                                         ...
# PA.NUS.PPP         World Development Indicators
# PA.NUS.PPPC.RF     World Development Indicators
# PA.NUS.PRVT.PP     World Development Indicators
#
# ...

# %%
wb.search_indicators('Kenya')
# Out:
# Empty DataFrame
# Columns: [name, unit, source, sourceNote, sourceOrganization, topics]
# Index: []

# %%
wb.get_series('SP.POP.TOTL', mrv=1)
# Out:
# Country                      Series             Year
# Africa Eastern and Southern  Population, total  2021    702976832.0
# Africa Western and Central   Population, total  2021    478185907.0
# Arab World                   Population, total  2021    456520777.0
#                                                            ...
# Yemen, Rep.                  Population, total  2021     32981641.0
# Zambia                       Population, total  2021     19473125.0
# Zimbabwe                     Population, total  2021     15993524.0
# Name: SP.POP.TOTL, Length: 266, dtype: float64

# %%
wb.get_series('SP.POP.TOTL', date='2016',
              id_or_value='id', simplify_index=True)
# Out:
# Country
# AFE    616377331.0
# AFW    419778384.0
# ARB    415077960.0
#           ...
# YEM     29274002.0
# ZMB     16767761.0
# ZWE     14452704.0
# Name: SP.POP.TOTL, Length: 266, dtype: float64
